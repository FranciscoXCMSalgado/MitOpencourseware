# %%
total_cost = float(input("What is the total cost of the house"))
portion_saved = float(input("What percentage of your monthly salary are you going to save"))
annual_sallary = float(input("What is your annual sallary"))
current_savings = 0
monthly_salary = annual_sallary / 12
r = 0.04
portion_down_payment = 0.25 * total_cost
total_months = 0

# %%
while current_savings < portion_down_payment:
    total_months += 1
    current_savings = portion_saved * monthly_salary  + current saving * r/12
    
print total_months

# %% [markdown]
# ### exercicio 1

# %%
total_cost = float(input("What is the total cost of the house"))
portion_saved = float(input("What percentage of your monthly salary are you going to save"))
annual_salary = float(input("What is your annual sallary"))
semi_annual_raise = float(input("What is your semi annual raise"))
current_savings = 0
monthly_salary = annual_sallary / 12
r = 0.04
portion_down_payment = 0.25 * total_cost
total_months = 0

# %%
while current_savings < portion_down_payment:
    total_months += 1
    if total_months %% 6 == 0:
        monthly_salary = monthly_salary * semi_annual_raise
        current_savings = portion_saved * monthly_salary  + current saving * r/12
    else:
        current_savings = portion_saved * monthly_salary  + current saving * r/12
    
    
print total_months

# %% [markdown]
# ### Exercicio 2

# %%
total_cost = 1000000
annual_salary = float(input("What is your annual sallary"))
semi_annual_raise = 0.07
current_savings = 0
monthly_salary = annual_sallary / 12
r = 0.04
portion_down_payment = 0.25 * total_cost
total_months = 0
portion_saved = 500

# %%
for i in range(0,36):
    total_months += 1
    if total_months %% 6 == 0:
        monthly_salary = monthly_salary * semi_annual_raise
        current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12 
    else:
        current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12

while abs(current_savings - portion_down_payment) > 0.01:
    if current_saving < portion_down_payment:
        portion_saved = 3/2 * portion saved
        for i in range(0,36):
        total_months += 1
        if total_months %% 6 == 0:
            monthly_salary = monthly_salary * semi_annual_raise
            current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12 
        else:
            current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12
    else:
        portion_saved = 1/2 * portion saved
        for i in range(0,36):
            total_months += 1
            if total_months %% 6 == 0:
                monthly_salary = monthly_salary * semi_annual_raise
                current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12 
            else:
                current_savings = portion_saved/10000 * monthly_salary  + current saving * r/12

print portion_saved/10000
